# %%
import numpy as np
import re
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %run PlottingMethods.ipynb

# %% [markdown]
# # Running code
#
# ##      <span style="color:orange">A.  LSA</span>
#
# ###      <span style="color:green"><u>Min Function</u></span>

# %%
best_y, curr_y, acceptance_pb, acc_best_sol, temp, runtime, iteration_nbr = processDataLSA("../java/SimulatedAnnealing/GraphData/LSA_MinFunction.txt")
drawPlotLSA(best_y, curr_y, temp, acceptance_pb, acc_best_sol)
